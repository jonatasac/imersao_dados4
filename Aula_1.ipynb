# %% [markdown]
# <a href="https://colab.research.google.com/github/jonatasac/imersao_dados4/blob/main/Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>**AULA 1**
# ### <center> Entendendo os dados
#
# ---
#
# <center>Análise e exploração de Dados de um anúncio de imóveis da cidade de São Paulo usando o Pandas e Python.
#
# [Dados utilizados já pré-limpos](https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv)
#
# [Base de dados original](https://www.kaggle.com/datasets/kaggleshashankk/house-price-data-of-sao-paulo)
#
# ---

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()  # Imprime as 5 primeiras linhas da tabela contida na nossa variável dados.
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados # Imprime todas as linhas da tabela contida na variável dados.
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados.sample() # Imprime uma amostra aleatória da nossa dataframe.
# Out:
#       Rua            Bairro     Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 9723  NaN  Jardim da Glória  São Paulo       445        3          6      4
#
#              Valor
# 9723  R$ 2.700.000

# %%
dados.sample(10) # Imprime 10 amostras aleatórias da nossa dataframe.
# Out:
#                                       Rua                    Bairro  \
# 6748                                  NaN                  Ferreira
# 7396                            Rua Tebas  Jardim Brasil (Zona Sul)
# 2497                           Rua França             Jardim Europa
# 3027                                  NaN         Alto de Pinheiros
# 9400          Rua Diogo Rodrigues Marques          Jardim Ernestina
# 7875              Avenida Nova Cantareira                  Tucuruvi
# 3715                                  NaN            Jardim Guedala
# 4561  Avenida Professor Fonseca Rodrigues         Alto de Pinheiros
# 887        Rua Antônio de Gouveia Giudice         Alto de Pinheiros
# 7109           Rua Inocêncio Nogueira, 0              Cidade Jardim
#
#          Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 6748  São Paulo       125        3          4      3
# 7396  São Paulo       400        3          6      6
# 2497  São Paulo       957        3          7     10
# ...

# %%
type(dados) # Exibe o tipo dos meus dados.
# Out:
# pandas.core.frame.DataFrame

# %%
dados["Bairro"] # Isola a minha coluna "Bairro" do DataFrame.
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
dados["Bairro"][6522] # Seleciona o Bairro do index ou linha 6522
# Out:
# 'Vila Paulo Silas'

# %%
dados.info() # Trás várias informações sobre os dados.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.Metragem # Outra forma de isolar uma coluna do DataFrame.
# Out:
# 0        1000
# 1         496
# 2         125
# 3         310
# 4         100
#          ...
# 10003      95
# 10004     605
# 10005     205
# 10006     185
# 10007     122
# Name: Metragem, Length: 10008, dtype: int64

# %%
dados.Metragem.mean() # Nos dá a média da coluna.
# Out:
# 442.30065947242207

# %%
dados["Bairro"] == "Vila Mariana" # Retorna False ou True se naquela linha tem "Vila Mariana"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
(dados["Bairro"] == "Vila Mariana") *1 # Transforma o booleano False ou True em 0 ou 1.
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10003    0
# 10004    0
# 10005    0
# 10006    0
# 10007    0
# Name: Bairro, Length: 10008, dtype: int64

# %%
sum(dados["Bairro"] == "Vila Mariana") # Realiza soma dos 0 e 1 e se tiver mais de 1 então tem "Vila Mariana" no DataFrame.
# Out:
# 184

# %%
tem_imoveis_vila = (dados["Bairro"] == "Vila Mariana") # Essa variável vai guardar a tabela que indica onde tem Vila Mariana.
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila] # Me mostra a tabela só com imóveis no Vila Mariana
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean() # Média da metragem dos imóveis no Vila Mariana
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts() 
# Conta o número de imóveis em cada bairro e retorna na nossa Series.
# E me fala logo abaixo em Lenght, quantos bairros tem na nossa DataFrame.
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()
# Nos mostra um gráfico com os 10 bairros com mais imóveis a venda.

# %% [markdown]
# ### <center>Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.groupby('Bairro').mean()['Metragem'] # Exercício 1
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
bairro_metragem = dados.groupby('Bairro').mean()['Metragem']
bairro_metragem.sample(10)
# Out:
# Bairro
# Vila Paulo Silas             403.333333
# Jardim Bélgica               205.600000
# Casa Verde                   306.000000
# Vila Aurora (Zona Norte)    1082.500000
# Jardim Monte Azul            322.500000
# Vila Alexandria              196.833333
# Instituto de Previdência     226.250000
# Jardim Guedala              2486.640199
# Jardim dos Estados           594.727273
# Vila Nelson                  280.000000
# Name: Metragem, dtype: float64

# %%
sem_rua = dados.isnull()['Rua']
por_bairro = dados[sem_rua].Bairro.value_counts()
por_bairro
# Exercício 5
# Out:
# Jardim Guedala                      190
# Alto de Pinheiros                   169
# Jardim Paulista                     138
# Jardim Europa                       128
# Jardim Leonor                       118
#                                    ...
# Jardim do Colégio (Zona Norte)        1
# Alto da Boa Vista                     1
# Jardim Aeroporto                      1
# Conjunto Residencial Vista Verde      1
# Jardim Santo Elias                    1
# Name: Bairro, Length: 394, dtype: int64

# %%
por_bairro.head(5).plot.pie()

# %%
dados.describe() # Exercício 4 - Mediana=50%
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %%
dados['Bairro'] # Exercício 2
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
dados.iloc[:, 1:2] # Exercício 2
# Out:
#                    Bairro
# 0       Planalto Paulista
# 1      Jardim dos Estados
# 2         Jardim Reimberg
# 3          Jardim Morumbi
# 4                   Mooca
# ...                   ...
# 10003          Vila Sofia
# 10004     Bosque da Saúde
# 10005       Vila da Saúde
# 10006       Vila Oratório
# 10007         Vila Alpina
#
# [10008 rows x 1 columns]

# %%
df=pd.DataFrame(dados,columns=["Bairro","Quartos","Vagas","Banheiros",])
df
# Out:
#                    Bairro  Quartos  Vagas  Banheiros
# 0       Planalto Paulista        4      6          8
# 1      Jardim dos Estados        4      4          4
# 2         Jardim Reimberg        4      2          3
# 3          Jardim Morumbi        3      4          2
# 4                   Mooca        3      2          2
# ...                   ...      ...    ...        ...
# 10003          Vila Sofia        2      2          2
# 10004     Bosque da Saúde        8      5          7
# 10005       Vila da Saúde        3      6          3
# 10006       Vila Oratório        3      2          2
# 10007         Vila Alpina        3      2          2
#
# [10008 rows x 4 columns]

# %%
media_df = df.groupby('Bairro').mean()
media_df
# Out:
#                     Quartos     Vagas  Banheiros
# Bairro
# Aclimação          3.318182  2.909091   3.079545
# Alto da Boa Vista  4.125000  4.625000   5.125000
# Alto da Lapa       3.151163  3.906977   3.790698
# Alto da Mooca      3.300000  3.650000   2.600000
# Alto de Pinheiros  3.938875  5.004890   4.838631
# ...                     ...       ...        ...
# Vila Água Funda    2.600000  2.600000   2.200000
# Água Branca        3.153846  2.461538   3.076923
# Água Fria          2.833333  2.500000   3.416667
# Água Funda         3.000000  2.000000   2.500000
# Água Rasa          3.500000  5.250000   3.250000
#
# [701 rows x 3 columns]

# %%
# Exercício 3
# Esse gráfico analisa os 15 primeiros bairros pela média de Quartos, vagas e banheiros de cada bairro, 
# podendo assim facilitar a nossa busca em qual bairro está o nosso imóvel ideal. 
# Poderíamos ter adicionado a coluna Metragem e Valor (após tratada) a nossa tabela, 
# mas o outlier ficaria muito maior, sendo assim é melhor fazer em outro gráfico e 
# após isso analisar os dois gráficos juntos.

# %%
media_df.head(15).plot.barh()
